# %% [markdown]
# <a href="https://colab.research.google.com/github/arco2121/Minister/blob/master/Minister.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# **# Installa dipendenze**

# %%
# !git clone https://github.com/arco2121/Minister.git

# %cd Minister

# !pip install -r requirements.txt

# !npm install
# Out:
# Cloning into 'Minister'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 95 (delta 37), reused 78 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (95/95), 54.21 KiB | 1.00 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# /content/Minister
# ...
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# added 66 packages, and audited 67 packages in 2s
# ⠙
# ⠙22 packages are looking for funding
# ⠙  run `npm fund` for details
# ⠙
# found 0 vulnerabilities
# ⠙npm notice
# npm notice New major version of npm available! 10.8.2 -> 11.13.0
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v11.13.0
# npm notice To update run: npm install -g npm@11.13.0
# npm notice
# ⠙

# %% [markdown]
# # Avvio

# %% [markdown]
# **# Training**

# %%
# !python3 model.py
# Out:
# Scaricamento dataset...
# ...
# 100% 143M/143M [00:01<00:00, 116MB/s]
# Extracting files...
# 100% 562M/562M [00:02<00:00, 247MB/s]
# Inizio addestramento su 416 classi usando cuda...
# Epoca [1/30] Step [0/1098] Loss: 6.0311
# Epoca [1/30] Step [200/1098] Loss: 1.3093

# %%
# !python3 routes.py
# Out:
#  * Serving Flask app 'routes'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:3000
# Press CTRL+C to quit
# ^C

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **# Avvio server**

# %%
import subprocess
import time

print("Avvio del server")
app_process = subprocess.Popen(['node', 'app.js'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

time.sleep(5)
print("Server pronto!")
# Out:
# Avvio del server
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_20609/2977077336.py in <cell line: 0>()
#       5 app_process = subprocess.Popen(['node', 'app.js'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#       6
# ----> 7 time.sleep(5)
#       8 print("Server pronto!")
#
# KeyboardInterrupt:

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(3000)
